# %% [markdown]
# Our goal is to take a Newick format tree file, which has unique accession IDs on each leaf node, and replace those accession IDs with a more human-readable name.

# %%
from pathlib import Path

from Bio import Phylo

# %%
# Our initial tree
treefile = Path("03_bootstrap.raxml.support")

# Load the tree into Bio.Phylo
tree = Phylo.read(treefile, "newick")

# %% [markdown]
# Read in the alternative names

# %%
with open("dictionary.tsv") as ifh:
    namedict = {k[:-1]:f"{v.strip()}|{k.split('|')[1]}" for k, v in (line.strip().split("\t") for line in ifh.readlines())}
    
list(namedict.items())[:10]
# Out:
# [('tr|A0A258M961|A0A258M961_9BURK',
#   'Ammonium transporter Polynucleobacter sp. 35-46-11|A0A258M961'),
#  ('tr|A0A2U9T2W9|A0A2U9T2W9_9GAMM',
#   'Ammonium transporter Lysobacter maris|A0A2U9T2W9'),
#  ('tr|A0A259IH62|A0A259IH62_9BURK',
#   'Ammonium transporter Polynucleobacter sp. 39-46-10|A0A259IH62'),
#  ('tr|A0A1H3EZE1|A0A1H3EZE1_LYSEN',
#   'Ammonium transporter Lysobacter enzymogenes|A0A1H3EZE1'),
#  ('tr|A0A1G3CU56|A0A1G3CU56_9BURK',
#   'Ammonium transporter Polynucleobacter sp. GWA2_45_21|A0A1G3CU56'),
#  ('tr|A0A0A0EY24|A0A0A0EY24_9GAMM',
#   'Ammonium transporter Lysobacter daejeonensis GH1-9|A0A0A0EY24'),
#  ('tr|A0A4R8F1T3|A0A4R8F1T3_9ENTR',
#   'Ammonium transporter Buttiauxella sp. BIGb0552|A0A4R8F1T3'),
#  ('tr|A0A1B7HUF3|A0A1B7HUF3_9ENTR',
#   'Ammonium transporter Buttiauxella gaviniae ATCC 51604|A0A1B7HUF3'),
#  ('tr|A0A1B7I1P1|A0A1B7I1P1_9ENTR',
#   'Ammonium transporter Buttiauxella noackiae ATCC 51607|A0A1B7I1P1'),
#  ('tr|A0A3S6EVI2|A0A3S6EVI2_YERET',
#   'Ammonium transporter Yersinia entomophaga|A0A3S6EVI2')]

# %% [markdown]
# We need to make sure all leaf node names are unique. One way to do this is to add arbitrary indexing (1, 2, 3, ..., etc.) to the end of the name.
#
# Another approach is to append the unique accession to the leaf name in an unobtrusive way.

# %% [markdown]
# Now let's swap the accession IDs out, replacing them with the human-readable names

# %%
for leaf in tree.get_terminals():
    try:
        leaf.name = namedict[leaf.name]
    except KeyError:
        pass
    
tree.get_terminals()[:5]
# Out:
# [Clade(branch_length=0.001254, name='Ammonium transporter Saccharomyces cerevisiae (strain Lal...'),
#  Clade(branch_length=1e-06, name='Ammonium transporter Saccharomyces cerevisiae x Saccharom...'),
#  Clade(branch_length=1e-06, name='Ammonium transporter Saccharomyces boulardii (nom. inval....'),
#  Clade(branch_length=0.07042, name='Ammonium transporter Saccharomyces eubayanus|A0A0L8RCS7'),
#  Clade(branch_length=0.057576, name='Ammonium transporter Saccharomyces arboricola (strain H-6...')]

# %%
Phylo.draw_ascii(tree)
# Out:
#  , Ammonium transporter Saccharomyces ce...
#  |
#  | Ammonium transporter Saccharomyces ce...
#  |
#  | Ammonium transporter Saccharomyces bo...
#  |
#  , Ammonium transporter Saccharomyces eu...
#  |
#  | Ammonium transporter Saccharomyces ar...
#  |
#  | Ammonium transporter Saccharomyces ce...
#  |
#  , Ammonium transporter Torulaspora sp. ...
#  |
#  , Ammonium transporter Zygosaccharomyce...
#  |
#  | Ammonium transporter Zygosaccharomyce...
#  |
#  | Ammonium transporter Zygosaccharomyce...
#  |
#  |, Ammonium transporter Debaryomyces han...
#  ||
#  || Ammonium transporter Debaryomyces fab...
#  ||
#  |, Ammonium transporter Meyerozyma guill...
#  ||
#  || Ammonium transporter Meyerozyma sp. J...
#  ||
#  || Ammonium transporter Suhomyces tanzaw...
#  ||
#  |, Ammonium transporter Lodderomyces elo...
#  ||
#  |, Ammonium transporter Candida orthopsi...
#  ||
#  || Ammonium transporter Candida parapsil...
#  ||
#  |, Ammonium transporter Candida maltosa ...
#  ||
#  || Ammonium transporter Candida albicans...
#  ,|
#  || Ammonium transporter Candida tropical...
#  ||
#  || Ammonium transporter Spathaspora sp. ...
#  ||
#  |, Ammonium transporter Candida auris|A0...
#  ||
#  || Ammonium transporter Candida auris|A0...
#  ||
#  || Ammonium transporter Metschnikowia bi...
#  ||
#  || Ammonium transporter Metschnikowia sp...
#  |
#  |  , Ammonium transporter Archaeoglobus fu...
#  |  |
#  |  |, Ammonium transporter Candidatus Entot...
#  |  ,|
#  |  || Ammonium transporter Candidatus Entot...
#  |  |
#  |  |                         , Rhesus blood group family type C glyc...
#  |  | ________________________|
#  |  ||                        , Rhesus blood group family type C glyc...
#  |  ||                        |
#  |  ||                        , RHCG isoform 2 Pan troglodytes|A0A6D2...
#  |  ||                        |
#  |  ||                        | RHCG isoform 2 Pongo abelii|A0A6D2Y2V3
#  |  ||
#  |  || Ammonium transporter Bacteroidetes ba...
#  |  ||
#  |  ||, Ammonium transporter Curvibacter sp. ...
#  |  |||
#  |  ||| Ammonium transporter Rhodoferax sp. T...
#  |  |||
#  |  ||| Ammonium transporter Rhodoferax sp. T...
#  |  |||
#  |  ||| Ammonium transporter Rhodoferax saide...
#  |  |,|
#  |  ||, Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||, Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  ||
#  |  ||, Ammonium transporter Hylemonella grac...
#  |  |||
#  |  ||| Ammonium transporter Hylemonella grac...
#  |  ||
#  |  || Ammonium transporter Ramlibacter tata...
#  |  ||
#  |  || Ammonium transporter Ramlibacter sp. ...
#  |  ||
#  |  |, Ammonium transporter Burkholderiales ...
#  |  ||
#  |  || Ammonium transporter Paucimonas lemoi...
#  |  ||
#  |  ||, Ammonium transporter Comamonas sp. JN...
#  |  |,|
#  |  ||| Ammonium transporter Comamonas sp. JU...
#  |  ||
#  |  || Ammonium transporter Amnimonas aquati...
#  |  ||
#  |  |, Ammonium transporter Azospira oryzae ...
#  |  ||
#  |  ||, Ammonium transporter Diaphorobacter s...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax ebreu...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. (...
#  |  |||
#  |  |,| Ammonium transporter Diaphorobacter p...
#  |  |||
#  |  ||| Ammonium transporter Comamonas sp. SC...
#  |  ||
#  |  || Ammonium transporter Acidovorax sp. M...
#  |  ||
#  |  || Ammonium transporter Comamonas sp. SC...
#  |  ||
#  |  || Ammonium transporter Simplicispira sp...
#  |  ||
#  |  |, Ammonium transporter Thauera sp. K11|...
#  |  ||
#  |  || Ammonium transporter Thauera linalool...
#  |  ||
#  |  || Ammonium transporter Schlegelella the...
#  |  ||
#  |  ||, Ammonium transporter Stenotrophomonas...
#  |  |||
#  |  ||| Ammonium transporter Stenotrophomonas...
#  |  |||
#  |  ||, Ammonium transporter Stenotrophomonas...
#  |  |,|
#  |  ||| Ammonium transporter Stenotrophomonas...
#  |  |||
#  |  ||| Ammonium transporter Pseudoxanthomona...
#  |  ||
#  |  ||, Ammonium transporter Lysobacter daeje...
#  |  |,|
#  |  ||| Ammonium transporter Lysobacter enzym...
#  |  ||
#  |  ||, Ammonium transporter Lysobacter alkal...
#  |  |||
#  |  ||| Ammonium transporter Lysobacter maris...
#  |  ||
#  |  |, Ammonium transporter Thauera sp.|A0A2...
#  |  ||
#  |  ||, Ammonium transporter Azoarcus communi...
#  |  |||
#  |  ||, Ammonium transporter Betaproteobacter...
#  |  |,|
#  |  ||| Ammonium transporter Azoarcus communi...
#  |  |||
#  |  ||| Ammonium transporter Azoarcus sp. DD4...
#  |  ||
#  |  ||, Ammonium transporter Rhodocyclaceae b...
#  |  |||
#  |  ||| Ammonium transporter Zoogloeaceae bac...
#  |  ||
#  |  || Ammonium transporter Betaproteobacter...
#  |  ||
#  |  ||, Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||, Ammonium transporter Polynucleobacter...
#  |  |,|
#  |  ||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||| Ammonium transporter Polynucleobacter...
#  |  ||
#  |  |, Ammonium transporter Tepidicella xavi...
#  |  ||
#  |  ||, Ammonium transporter Tepidimonas igna...
#  |  |||
#  |  ||| Ammonium transporter Tepidimonas font...
#  |  ||
#  |  ||, Ammonium transporter Betaproteobacter...
#  |  |||
#  |  |,, Ammonium transporter Comamonadaceae b...
#  |  |||
#  |  ||| Ammonium transporter Comamonadaceae b...
#  |  |||
#  |  ||| Ammonium transporter Comamonadaceae b...
#  |  ||
#  |  |, Ammonium transporter Hydrogenophaga s...
#  |  ||
#  |  ||, Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||, Ammonium transporter Betaproteobacter...
#  |  |||
#  |  ||| Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||| Ammonium transporter Betaproteobacter...
#  |  |||
#  |  ||, Ammonium transporter Hydrogenophaga s...
#  |  |||
#  |  ||| Ammonium transporter Hydrogenophaga s...
#  |  ||
#  |  |, Ammonium transporter Tibeticola sedim...
#  |  ||
#  |  ||, Ammonium transporter Curvibacter sp. ...
#  |  |||
#  |  |,| Ammonium transporter Polaromonas sp. ...
#  |  |||
#  |  ||| Ammonium transporter Curvibacter sp. ...
#  |  ||
#  |  || Ammonium transporter Curvibacter sp. ...
#  |  ||
#  |  ||, Ammonium transporter Sphaerotilus hip...
#  |  |||
#  |  ||| Ammonium transporter Sphaerotilus nat...
#  |  |||
#  |  ||, Ammonium transporter Aquabacterium sp...
#  |  |||
#  |  ||| Ammonium transporter Aquabacterium co...
#  |  |||
#  |__||| Ammonium transporter Burkholderiales ...
#  |  |||
#  |  |,| Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||, Ammonium transporter Hydrogenophaga s...
#  |  |||
#  |  ||, Ammonium transporter Roseateles sp. Y...
#  |  |||
#  |  ||| Ammonium transporter Roseateles aquat...
#  |  |||
#  |  ||, Ammonium transporter Roseateles depol...
#  |  |||
#  |  ||, Ammonium transporter Pelomonas sp. HM...
#  |  |||
#  |  ||| Ammonium transporter Pelomonas sp. Ro...
#  |  |||
#  |  ||| Ammonium transporter Pelomonas sp. Ro...
#  |  |||
#  |  ||, Ammonium transporter Paucibacter aqua...
#  |  |||
#  |  ||| Ammonium transporter Paucibacter sp. ...
#  |  ||
#  |  ||, Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||| Ammonium transporter Burkholderiales ...
#  |  ||
#  |  ||, Ammonium transporter Polaromonas sp. ...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. 1...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. 1...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax delaf...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. 5...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. H...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. 9...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. H...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax kalam...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. G...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. F...
#  |  |||
#  |  ||, Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. S...
#  |  |||
#  |  ||, Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. 9...
#  |  |||
#  |  ||| Ammonium transporter Burkholderiales ...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. R...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax tempe...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax tempe...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. 1...
#  |  |||
#  |  ||, Ammonium transporter Acidovorax sp. 6...
#  |  |||
#  |  ||| Ammonium transporter Acidovorax sp. 5...
#  |  |||
#  |  ||, Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  |||
#  |  ||| Ammonium transporter Limnohabitans sp...
#  |  ||
#  |  ||, Ammonium transporter Methylibium sp. ...
#  |  |,|
#  |  ||, Ammonium transporter Methylibium petr...
#  |  |||
#  |  ||| Ammonium transporter Methylibium sp. ...
#  |  ||
#  |  ||, Ammonium transporter Rivibacter subsa...
#  |  |||
#  |  ||| Ammonium transporter Burkholderiales ...
#  |  |||
#  |  |,| Ammonium transporter Methylibium sp. ...
#  |  |||
#  |  ||, Ammonium transporter Rhizobacter sp. ...
#  |  |||
#  |  ||| Ammonium transporter Rhizobacter sp. ...
#  |  ||
#  |  ||, Ammonium transporter Pseudacidovorax ...
#  |  |||
#  |  ||| Ammonium transporter Pseudacidovorax ...
#  |  ||
#  |  ||, Ammonium transporter Variovorax sp. J...
#  |  |||
#  |  ||, Ammonium transporter Variovorax sp. Y...
#  |  |||
#  |  ||, Ammonium transporter Variovorax sp. C...
#  |  |||
#  |  ||, Ammonium transporter Variovorax sp. P...
#  |  |||
#  |  ||, Ammonium transporter Variovorax sp. 7...
#  |  |||
#  |  ||, Ammonium transporter Variovorax parad...
#  |  |||
#  |  ||| Ammonium transporter Variovorax parad...
#  |  |||
#  |  ||| Ammonium transporter Variovorax parad...
#  |  |||
#  |  ||, Ammonium transporter Variovorax sp. O...
#  |  |||
#  |  ||| Ammonium transporter Variovorax sp. R...
#  |  |||
#  |  ||| Ammonium transporter Variovorax parad...
#  |  |||
#  |  ||| Ammonium transporter Variovorax beiji...
#  |  ||
#  |  |, Ammonium transporter Lautropia sp. SC...
#  |  ||
#  |  || Ammonium transporter Zhizhongheella c...
#  |  ||
#  |  |, Ammonium transporter Rhodocyclales ba...
#  |  ||
#  |  |, Ammonium transporter Methyloversatili...
#  |  ||
#  |  ||, Ammonium transporter Solimicrobium si...
#  |  |,|
#  |  ||| Ammonium transporter Undibacterium pi...
#  |  ||
#  |  ||, Ammonium transporter Duganella sp. CF...
#  |  |||
#  |  ||| Ammonium transporter Duganella sp. Ro...
#  |  |||
#  |  ||| Ammonium transporter Duganella sp. Ro...
#  |  |||
#  |  ||| Ammonium transporter Massilia sp. CF0...
#  |  |,|
#  |  ||, Ammonium transporter Massilia sp. Roo...
#  |  |||
#  |  ||| Ammonium transporter Massilia namucuo...
#  |  |||
#  |  ||| Ammonium transporter Massilia sp. Roo...
#  |  ||
#  |  ||, Ammonium transporter Duganella sp. OV...
#  |  |||
#  |  ||, Ammonium transporter Duganella sp. Le...
#  |  |||
#  |  ||| Ammonium transporter Duganella sp. Le...
#  |  |,|
#  |  ||| Ammonium transporter Duganella saccha...
#  |  |||
#  |  ||| Ammonium transporter Duganella sp. CF...
#  |  ||
#  |  || Ammonium transporter Duganella sp. CF...
#  |  ||
#  |  ||, Ammonium transporter Rugamonas rubra|...
#  |  |||
#  |  ||| Ammonium transporter Janthinobacteriu...
#  |  ||
#  |  ||, Ammonium transporter Herminiimonas fo...
#  |  |||
#  |  |,| Ammonium transporter Noviherbaspirill...
#  |  |||
#  |  ||| Ammonium transporter Oxalobacteraceae...
#  |  ||
#  |  || Ammonium transporter Noviherbaspirill...
#  |  ||
#  |  ||, Ammonium transporter Massilia glaciei...
#  |  |,|
#  |  ||, Ammonium transporter Massilia psychro...
#  |  |||
#  |  ||| Ammonium transporter Massilia eurypsy...
#  |  ||
#  |  ||, Ammonium transporter Massilia sp. PDC...
#  |  |||
#  |  ||| Ammonium transporter Massilia phospha...
#  |  |||
#  |  ||| Ammonium transporter Massilia sp. JS1...
#  |  |||
#  |  |,| Ammonium transporter Massilia sp. Roo...
#  |  |||
#  |  ||| Ammonium transporter Herbaspirillum s...
#  |  ||
#  |  ||, Ammonium transporter Massilia sp. LC2...
#  |  |||
#  |  ||| Ammonium transporter Massilia sp. KIM...
#  |  |||
#  |  ||, Ammonium transporter Massilia sp. Mn1...
#  |  |||
#  |  ||| Ammonium transporter Massilia sp. Lea...
#  |  ||
#  |  ||, Ammonium transporter Janthinobacteriu...
#  |  |||
#  |  ||| Ammonium transporter Janthinobacteriu...
#  |  |||
#  |  ||| Ammonium transporter Janthinobacteriu...
#  |  ,|
#  |  ||, Ammonium transporter Dechloromonas sp...
#  |  |||
#  |  ||, Ammonium transporter Dechloromonas ar...
#  |  |||
#  |  ||| Ammonium transporter Betaproteobacter...
#  |  |||
#  |  ||, Ammonium transporter Ephemera danica|...
#  |  |||
#  |  ||| Ammonium transporter Rhodocyclaceae b...
#  |  |,|
#  |  ||| Ammonium transporter Candidatus Accum...
#  |  |||
#  |  ||| Ammonium transporter Propionivibrio d...
#  |  ||
#  |  ||, Ammonium transporter Fluviicoccus keu...
#  |  |||
#  |  ||| Ammonium transporter Agitococcus lubr...
#  |  |||
#  |  ||, Ammonium transporter Janthinobacteriu...
#  |  |||
#  |  ||, Ammonium transporter Iodobacter sp. B...
#  |  |||
#  |  ||| Ammonium transporter Iodobacter fluvi...
#  |  |||
#  |  ||, Ammonium transporter Plesiomonas shig...
#  |  |||
#  |  ||| Ammonium transporter Plesiomonas shig...
#  |  ||
#  |  |, Ammonium transporter Rhodocyclaceae b...
#  |  ||
#  |  || Ammonium transporter Sulfurisoma sedi...
#  |  ||
#  |  || Ammonium transporter Betaproteobacter...
#  |  ||
#  |  |, Ammonium transporter Betaproteobacter...
#  |  ||
#  |  ||, Ammonium transporter Zoogloea oleivor...
#  |  |||
#  |  ||, Ammonium transporter Paraburkholderia...
#  |  |||
#  |  ||| Ammonium transporter Paraburkholderia...
#  |  ||
#  |  |, Ammonium transporter Betaproteobacter...
#  |  ||
#  |  || Ammonium transporter Betaproteobacter...
#  |  ||
#  |  |, Ammonium transporter Betaproteobacter...
#  |  ||
#  |  || Ammonium transporter Betaproteobacter...
#  |  ||
#  |  |, Ammonium transporter Tahibacter aquat...
#  |  ||
#  |  ||, Ammonium transporter Pandoraea apista...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea fibros...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea bronch...
#  |  |||
#  |  ||, Ammonium transporter Pandoraea soli|A...
#  |  |||
#  |  ||, Ammonium transporter Pandoraea cepali...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea eparur...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea terrig...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea faecig...
#  |  |||
#  |  ||, Ammonium transporter Pandoraea aquati...
#  |  |||
#  |  ||, Ammonium transporter Pandoraea commov...
#  |  |||
#  |  |,| Ammonium transporter Pandoraea oxalat...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea pneumo...
#  |  |||
#  |  ||| Ammonium transporter Pandoraea nosoer...
#  |  ||
#  |  || Ammonium transporter Pandoraea terrae...
#  |  ||
#  |  |, Ammonium transporter Cupriavidus sp. ...
# _|  ||
#  |  ||, Ammonium transporter Cupriavidus neca...
#  |  |,|
#  |  ||| Ammonium transporter Cupriavidus lacu...
#  |  ||
#  |  || Ammonium transporter Cupriavidus sp. ...
#  |  ||
#  |  ||, Ammonium transporter Collimonas sp. P...
#  |  |||
#  |  ||, Ammonium transporter Collimonas sp. O...
#  |  |||
#  |  ||| Ammonium transporter Collimonas sp. O...
#  |  |||
#  |  ||| Ammonium transporter Collimonas sp. O...
#  |  |||
#  |  ||| Ammonium transporter Collimonas arena...
#  |  |||
#  |  ||| Ammonium transporter Collimonas sp. O...
#  |  |||
#  |  ||, Ammonium transporter beta proteobacte...
#  |  |||
#  |  |||, Ammonium transporter Polynucleobacter...
#  |  ||||
#  |  |||| Ammonium transporter Polynucleobacter...
#  |  ||,|
#  |  |||, Ammonium transporter Polynucleobacter...
#  |  ||||
#  |  |||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  |||, Ammonium transporter Polynucleobacter...
#  |  ||||
#  |  |||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||, Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||, Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||| Ammonium transporter Polynucleobacter...
#  |  |||
#  |  ||| Ammonium transporter Glaciimonas sp. ...
#  |  ||
#  |  |, Ammonium transporter Burkholderiales ...
#  |  ||
#  |  ||, ATP phosphoribosyltransferase Beauver...
#  |  |||
#  |  ||, Ammonium transporter Buttiauxella noa...
#  |  |||
#  |  ||| Ammonium transporter Buttiauxella sp....
#  |  |||
#  |  ||| Ammonium transporter Enterobacter sp....
#  |  |||
#  |  ||, Ammonium transporter Klebsiella aerog...
#  |  |||
#  |  ||| Ammonium transporter Klebsiella aerog...
#  |  |||
#  |  ||, Ammonium transporter Klebsiella sp. H...
#  |  |||
#  |  ||, Ammonium transporter Klebsiella varii...
#  |  |||
#  |  ||| Ammonium transporter Klebsiella varii...
#  |  |||
#  |  ||, Ammonium transporter Klebsiella pneum...
#  |  |||
#  |  ||| Ammonium transporter Klebsiella pneum...
#  |  |||
#  |  ||, Ammonium transporter Klebsiella pneum...
#  |  |||
#  |  ||| Ammonium transporter Klebsiella pneum...
#  |  |||
#  |  ||, Ammonium transporter Klebsiella sp. L...
#  |  |||
#  |  ||| Ammonium transporter Enterobacteriace...
#  |  |||
#  |  ||, Ammonium transporter Raoultella plant...
#  |  |||
#  |  ||| Ammonium transporter Raoultella ornit...
#  |  |||
#  |  ||, Ammonium transporter bacteria symbion...
#  |  |||
#  |  ||| Ammonium transporter Erwinia sp. OLMD...
#  |  |||
#  |  ||, Ammonium transporter Erwinia sp. OLSS...
#  |  |||
#  |  ||| Ammonium transporter Erwinia persicin...
#  |  |||
#  |  ||| Ammonium transporter Erwinia rhaponti...
#  |  |||
#  |  ||| Ammonium transporter Erwinia sp. Leaf...
#  |  |||
#  |  ||, Ammonium transporter Erwinia sp. JUb2...
#  |  |||
#  |  ||| Ammonium transporter Pantoea coffeiph...
#  |  |||
#  |  ||, Ammonium transporter Erwinia mallotiv...
#  |  |||
#  |  ||, Ammonium transporter Erwinia tracheip...
#  |  |||
#  |  ||| Ammonium transporter Erwinia tracheip...
#  |  |||
#  |  ||| Ammonium transporter Erwinia typograp...
#  |  |||
#  |  ||, Ammonium transporter Enterobacterales...
#  |  |||
#  |  ||| Ammonium transporter Erwiniaceae bact...
#  |  |||
#  |  ||, Ammonium transporter [Pantoea] beijin...
#  |  |||
#  |  ||| Ammonium transporter Erwinia iniecta|...
#  |  |||
#  |  ||, Ammonium transporter Mixta theicola|A...
#  |  |,|
#  |  ||| Ammonium transporter Pantoea alhagi|A...
#  |  |||
#  |  ||| Ammonium transporter Mixta gaviniae|A...
#  |  |||
#  |  ||, Ammonium transporter Pantoea conspicu...
#  |  |||
#  |  ||, Ammonium transporter Pantoea latae|A0...
#  |  |||
#  |  ||| Ammonium transporter Pantoea sp. PSNI...
#  |  |||
#  |  |||, Ammonium transporter Rosenbergiella n...
#  |  ||,|
#  |  |||, Ammonium transporter bacteria symbion...
#  |  ||||
#  |  |||| Ammonium transporter Tatumella sp. OP...
#  |  |||
#  |  ||, Ammonium transporter Tatumella citrea...
#  |  |||
#  |  ||| Ammonium transporter Tatumella morbir...
#  |  |||
#  |  ||, Ammonium transporter Pantoea sp. VS1|...
#  |  |||
#  |  ||| Ammonium transporter Pantoea dispersa...
#  |  |||
#  |  ||, Ammonium transporter Pantoea sp. (str...
#  |  |||
#  |  ||, Ammonium transporter Pantoea sp. MSR2...
#  |  |||
#  |  ||| Ammonium transporter Pantoea sp. AS-P...
#  |  |||
#  |  ||, Ammonium transporter Yersinia ruckeri...
#  |  |||
#  |  |||, Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||| Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||| Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||, Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||| Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||| Ammonium transporter Morganella morga...
#  |  ||||
#  |  |||, Ammonium transporter Xenorhabdus maul...
#  |  ||||
#  |  |||, Ammonium transporter Xenorhabdus eapo...
#  |  ||||
#  |  |||| Ammonium transporter Xenorhabdus ishi...
#  |  ||||
#  |  |||| Ammonium transporter Xenorhabdus thuo...
#  |  ||||
#  |  |||, Ammonium transporter Xenorhabdus ehle...
#  |  ||||
#  |  ||,| Ammonium transporter Xenorhabdus sp. ...
#  |  ||||
#  |  |||| Ammonium transporter Xenorhabdus kozo...
#  |  ||||
#  |  |||| Ammonium transporter Xenorhabdus homi...
#  |  ||||
#  |  |||, Ammonium transporter Photorhabdus thr...
#  |  ||||
#  |  |||| Ammonium transporter Photorhabdus tem...
#  |  ||||
#  |  |||, Ammonium transporter Photorhabdus kha...
#  |  ||||
#  |  |||| Ammonium transporter Photorhabdus kha...
#  |  ||||
#  |  |||, Ammonium transporter Providencia snee...
#  |  ||||
#  |  |||, Ammonium transporter Providencia rett...
#  |  ||||
#  |  |||| Ammonium transporter Providencia rett...
#  |  ||||
#  |  |||| Ammonium transporter Providencia rett...
#  |  ||||
#  |  |||, Ammonium transporter Moellerella wisc...
#  |  ||||
#  |  |||| Ammonium transporter Moellerella wisc...
#  |  ||||
#  |  |||| Ammonium transporter Gilliamella apic...
#  |  ||||
#  |  |||, Ammonium transporter Proteus myxofaci...
#  |  ||||
#  |  |||| Ammonium transporter Proteus hauseri|...
#  |  ||||
#  |  |||| Ammonium transporter Proteus mirabili...
#  |  ||||
#  |  |||| Ammonium transporter Providencia alca...
#  |  |||
#  |  ||| Ammonium transporter Yersinia entomop...
#  |  |||
#  |  ||, Ammonium transporter Leminorella grim...
#  |  |||
#  |  |||, Ammonium transporter Enterobacteriace...
#  |  ||,|
#  |  |||| Ammonium transporter Hafnia alvei ATC...
#  |  |||
#  |  |||, Ammonium transporter Hafnia alvei FB1...
#  |  ||||
#  |  |||| Ammonium transporter Hafnia alvei|A0A...
#  |  ||||
#  |  |||| Ammonium transporter Hafnia alvei|A0A...
#  |  |||
#  |  ||, Ammonium transporter Yersinia massili...
#  |  |||
#  |  |||, Ammonium transporter Yersinia pestis ...
#  |  ||,|
#  |  |||| Ammonium transporter Yersinia pseudot...
#  |  |||
#  |  |||, Ammonium transporter Yersinia enteroc...
#  |  ||||
#  |  ||,| Ammonium transporter Yersinia kristen...
#  |  ||||
#  |  |||| Ammonium transporter Yersinia enteroc...
#  |  |||
#  |  ||, Ammonium transporter Yersinia frederi...
#  |  |||
#  |  ||| Ammonium transporter Yersinia frederi...
#  |  |||
#  |  ||, Ammonium transporter Yersinia enteroc...
#  |  |||
#  |  ||| Ammonium transporter Yersinia interme...
#  |  |||
#  |  ||, Ammonium transporter Yersinia bercovi...
#  |  |||
#  |  ||| Ammonium transporter Yersinia mollare...
#  |  |||
#  |  ||, Ammonium transporter Biostraticola to...
#  |  |||
#  |  ||| Ammonium transporter Sodalis praecapt...
#  |  |||
#  |  ||, Ammonium transporter Rahnella sp. AA|...
#  |  |||
#  |  ||, Ammonium transporter Rahnella aquatil...
#  |  |||
#  |  ||| Ammonium transporter Rahnella sp. (st...
#  |  |||
#  |  ||| Ammonium transporter Serratia sp. Lea...
#  |  |||
#  |  ||, Ammonium transporter Serratia sp. M24...
#  |  |||
#  |  ||| Ammonium transporter Rouxiella silvae...
#  |  |||
#  |  ||| Ammonium transporter Rouxiella badens...
#  |  |||
#  |  ||, Ammonium transporter Nissabacter sp. ...
#  |  |||
#  |  ||, Ammonium transporter Chimaeribacter a...
#  |  |||
#  |  ||| Ammonium transporter Chimaeribacter c...
#  |  |||
#  |  ||| Ammonium transporter Chimaeribacter c...
#  |  ||
#  |  ||, Ammonium transporter Pusillimonas noe...
#  |  |||
#  |  ||, Ammonium transporter Pusillimonas sp....
#  |  |,|
#  |  ||| Ammonium transporter Pusillimonas sp....
#  |  |||
#  |  ||| Ammonium transporter Advenella kashmi...
#  |  ||
#  |  || Ammonium transporter Pigmentiphaga sp...
#  |  ||
#  |  ||, Ammonium transporter plant metagenome...
#  |  |||
#  |  ||| Ammonium transporter plant metagenome...
#  |  |||
#  |  ||| Ammonium transporter Orrella dioscore...
#  |  |||
#  |  ||| Ammonium transporter plant metagenome...
#  |  |,|
#  |  ||, Ammonium transporter Corticimicrobact...
#  |  |||
#  |  ||| Ammonium transporter Alcaligenes sp. ...
#  |  |||
#  |  ||| Ammonium transporter Kerstersia gyior...
#  |  ||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||| Ammonium transporter Achromobacter ar...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||| Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||| Ammonium transporter Alcaligenes xylo...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||| Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||, Ammonium transporter Alcaligenes xylo...
#  |  |||
#  |  ||| Ammonium transporter Achromobacter in...
#  |  |||
#  |  ||, Ammonium transporter Achromobacter sp...
#  |  |||
#  |  ||| Ammonium transporter Achromobacter pu...
#  |  |||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella bronc...
#  |  |||
#  |  ||, Ammonium transporter Bordetella genom...
#  |  |||
#  |  ||| Ammonium transporter Bordetella sp. N...
#  |  |||
#  |  ||| Ammonium transporter Bordetella flabi...
#  |  ||
#  |  || Ammonium transporter Paracoccus zheji...
#  |  ||
#  |  |, Ammonium transporter Pseudomonas sp. ...
#  |  ||
#  |  || Ammonium transporter Pseudomonas lalk...
#  |  ||
#  |  |, Ammonium transporter Pseudomonas alky...
#  |  ||
#  |  || Ammonium transporter Pseudomonas sp. ...
#  |  ||
#  |  |, Ammonium transporter Pseudomonas dong...
#  |  ||
#  |  || Ammonium transporter Pseudomonas sp. ...
#  |  ||
#  |  |, Ammonium transporter Pseudomonas vran...
#  |  ||
#  |  || Ammonium transporter Pseudomonas sp. ...
#  |  ||
#  |  || Ammonium transporter Pseudomonas sp. ...
#  |  ||
#  |  || Ammonium transporter Pseudomonas alky...
#  |  ||
#  |  |, Ammonium transporter Parasulfuritortu...
#  |  ||
#  |  |, Ammonium transporter Rhodospirillacea...
#  |  ||
#  |  ||, Ammonium transporter Mesorhizobium hu...
#  |  |||
#  |  ||| Ammonium transporter Mesorhizobium sp...
#  |  ||
#  |  |, Ammonium transporter Rhodospirillacea...
#  |  ||
#  |  || Ammonium transporter Bauldia litorali...
#  |  ||
#  |  |, Ammonium transporter Methylovorus sp....
#  |  ||
#  |  || Ammonium transporter Nitrobacter vulg...
#  |  ||
#  |  |, Ammonium transporter Azospirillum bra...
#  |  ||
#  |  || Ammonium transporter Azospirillum bra...
#  |  ||
#  |  |, Ammonium transporter Azospirillum bra...
#  |  ||
#  |  || Ammonium transporter Azospirillum bra...
#  |  ||
#  |  |, Ammonium transporter Azospirillum lip...
#  |  ||
#  |  |, Ammonium transporter Azospirillum thi...
#  |  ||
#  |  || Ammonium transporter Azospirillum ram...
#  |  ||
#  |  || Ammonium transporter Skermanella stib...
#  |  ||
#  |  ||, Ammonium transporter Inquilinus limos...
#  |  |,|
#  |  ||| Ammonium transporter Inquilinus limos...
#  |  ||
#  |  || Ammonium transporter Burkholderia sp....
#  |  ||
#  |  ||_ Ammonium_transp domain-containing pro...
#  |  ||
#  |  || Ammonium transporter Ferrovibrio terr...
#  |  ||
#  |  |, Ammonium transporter Caenispirillum b...
#  |  ||
#  |  |, Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  |, Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  |, Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  |, Ammonium transporter Magnetospirillum...
#  |  ||
#  |  || Ammonium transporter Magnetospirillum...
#  |  ||
#  |  |, Ammonium transporter Roseomonas aestu...
#  |  ||
#  |  || Ammonium transporter Roseomonas deser...
#  |  ||
#  |  || Ammonium transporter Roseomonas stagn...
#  |  ||
#  |  || Ammonium transporter Belnapia rosea|A...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  || Ammonium transporter Pseudogulbenkian...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  || Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  ||, Ammonium transporter Chromobacterium ...
#  |  |||
#  |  ||| Ammonium transporter Chromobacterium ...
#  |  |||
#  |  |,| Ammonium transporter Chromobacterium ...
#  |  |||
#  |  ||| Ammonium transporter Chromobacterium ...
#  |  ||
#  |  || Ammonium transporter Chromobacterium ...
#  |  ||
#  |  || Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Chromobacterium ...
#  |  ||
#  |  || Ammonium transporter Chromobacterium ...
#  |  ||
#  |  |, Ammonium transporter Crenobacter cave...
#  |  ||
#  |  || Ammonium transporter Gulbenkiania ind...
#  |  |
#  |  |, Ammonia channel protein Peptococcacea...
#  |  ||
#  |  || Ammonium transporter Firmicutes bacte...
#  |  ||
#  |  |, Ammonium transporter Desulfotomaculum...
#  |  ||
#  |  || Ammonium transporter Desulfotomaculum...
#  |   |
#  |   , Ammonium transporter Nitrospiraceae b...
#  |   |
#  |   | Ammonium transporter Deltaproteobacte...
#  |   |
#  |   | Ammonium transporter bacterium|A0A522...
#  |
#  , Ammonium transporter Lachancea quebec...
#  |
#  | Ammonium transporter Lachancea thermo...
#  |
#  | Ammonium transporter Saccharomyces ce...

# %% [markdown]
# Write out the new, modified tree.

# %%
Phylo.write(tree, "transporter_tree_renamed.new", "newick")
# Out:
# 1

# %%
# !ls
# Out:
# 03_bootstrap.raxml.bestTree
# 03_bootstrap.raxml.bootstraps
# 03_bootstrap.raxml.support
# 5-8-22-Harris-agenda_LP.docx
# RAxML_bipartitionsBranchLabels.output-3_bootstrap.tre
# dictionary.tsv
# rename_tree_leaves.ipynb
# transporter_tree_renamed.new
